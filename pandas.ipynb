# %% [markdown]
# ## Pandas
# ### **Leitura**
# ```python
# import pandas as pd
#
# dados = pd.read_csv('arquivo.csv')  # Ler CSV
# dados = pd.read_excel('arquivo.xlsx')  # Ler Excel

# %%
import pandas as pd

# %%
#carrega arquivo para dataframe Pandas
dados = pd.read_excel(r"C:\Users\orfeu\Desktop\TTPE\grupo6dnv.xlsx")
#formato
dados.shape
# Out:
# (78, 15)

# %%
#resumo estatístico de colunas numericas
dados.describe
# Out:
# <bound method NDFrame.describe of      id Entrevistador_nome  Entrevistador_matrícula  grupo  \
# 0    19     Gisele Andrade                   566657      6
# 1    21     Gisele Andrade                   566657      6
# 2    24     Gisele Andrade                   566657      6
# 3    29     Gisele Andrade                   566657      6
# 4    36     Gisele Andrade                   566657      6
# ..  ...                ...                      ...    ...
# 73  210        Victor Hugo                   569696      6
# 74  214        Victor Hugo                   569696      6
# 75  241        Victor Hugo                   569696      6
# 76  634        Victor Hugo                   569696      6
# 77  638        Victor Hugo                   569696      6
#
#     DEntrevistado_curso           Satisfação_curso  Idade     Gênero  \
# 0            Jornalismo           Muito satisfeito     20  Masculino
# 1       Educação Física    Parcialmente satisfeito     21   Feminino
# ...

# %%
#primeiros registros
dados.head()
# Out:
#    id Entrevistador_nome  Entrevistador_matrícula  grupo  DEntrevistado_curso  \
# 0  19     Gisele Andrade                   566657      6           Jornalismo
# 1  21     Gisele Andrade                   566657      6      Educação Física
# 2  24     Gisele Andrade                   566657      6  Ciências Ambientais
# 3  29     Gisele Andrade                   566657      6  Ciências Ambientais
# 4  36     Gisele Andrade                   566657      6  Ciências Biológicas
#
#           Satisfação_curso  Idade     Gênero Moradia anterior  \
# 0         Muito satisfeito     20  Masculino        Fortaleza
# 1  Parcialmente satisfeito     21   Feminino        Fortaleza
# 2  Parcialmente satisfeito     25   Feminino        Fortaleza
# 3         Muito satisfeito     22   Feminino        Fortaleza
# 4  Parcialmente satisfeito     19  Masculino            Outro
#
#                                    Encontro  A qualidade da sua vida  \
# ...

# %%
#últimos registros com parâmetros
dados.tail(2)
# Out:
#      id Entrevistador_nome  Entrevistador_matrícula  grupo  \
# 76  634        Victor Hugo                   569696      6
# 77  638        Victor Hugo                   569696      6
#
#    DEntrevistado_curso           Satisfação_curso  Idade     Gênero  \
# 76            Farmácia           Muito satisfeito     18   Feminino
# 77            Economia  Parcialmente insatisfeito     19  Masculino
#
#                                    Moradia anterior    Encontro  \
# 76                Região metropolitana de Fortaleza  Assistindo
# 77  Meio Urbano, em uma cidade do interior do Ceará  Assistindo
#
#     A qualidade da sua vida           Interação social        Alimentação  \
# 76  nem melhorou nem piorou          Aumentou um pouco  Melhorou um pouco
# 77  nem melhorou nem piorou  nem aumentou nem diminuiu  Melhorou um pouco
#
#                Saude mental         Convívio família
# 76  nem melhorou nem piorou        Melhorou um pouco
# ...

# %%
# Filtrar por nome da coluna
coluna_desejada = dados[["Entrevistador_nome"]]

# Remover duplicatas na coluna específica
coluna_desejada_sem_duplicatas = coluna_desejada.drop_duplicates()

# Exibir as primeiras linhas da coluna sem duplicatas
print(coluna_desejada_sem_duplicatas.head())
# Out:
#    Entrevistador_nome
# 0      Gisele Andrade
# 11            Heloísa
# 47              Orfeu
# 63         João Pedro
# 73        Victor Hugo

# %%
#linhas 1, 2 e 3
dados.loc[[1,2,3]]
# Out:
#    id Entrevistador_nome  Entrevistador_matrícula  grupo  DEntrevistado_curso  \
# 1  21     Gisele Andrade                   566657      6      Educação Física
# 2  24     Gisele Andrade                   566657      6  Ciências Ambientais
# 3  29     Gisele Andrade                   566657      6  Ciências Ambientais
#
#           Satisfação_curso  Idade    Gênero Moradia anterior  \
# 1  Parcialmente satisfeito     21  Feminino        Fortaleza
# 2  Parcialmente satisfeito     25  Feminino        Fortaleza
# 3         Muito satisfeito     22  Feminino        Fortaleza
#
#                                    Encontro  A qualidade da sua vida  \
# 1                       Iniciação acadêmica  nem melhorou nem piorou
# 2                                Assistindo        Melhorou bastante
# 3  Iniciação em desenvolvimento tecnológico        Melhorou bastante
#
#     Interação social              Alimentação             Saude mental  \
# ...

# %%
#linhas por range
dados.loc[1:5]
# Out:
#    id Entrevistador_nome  Entrevistador_matrícula  grupo  \
# 1  21     Gisele Andrade                   566657      6
# 2  24     Gisele Andrade                   566657      6
# 3  29     Gisele Andrade                   566657      6
# 4  36     Gisele Andrade                   566657      6
# 5  39     Gisele Andrade                   566657      6
#
#               DEntrevistado_curso           Satisfação_curso  Idade  \
# 1                 Educação Física    Parcialmente satisfeito     21
# 2             Ciências Ambientais    Parcialmente satisfeito     25
# 3             Ciências Ambientais           Muito satisfeito     22
# 4             Ciências Biológicas    Parcialmente satisfeito     19
# 5  Engenharia de Telecomunicações  Parcialmente insatisfeito     19
#
#       Gênero Moradia anterior                                  Encontro  \
# 1   Feminino        Fortaleza                       Iniciação acadêmica
# ...

# %%
#filtro
dados.loc[dados['DEntrevistado_curso'] == "Ciências Ambientais"]
# Out:
#      id Entrevistador_nome  Entrevistador_matrícula  grupo  \
# 2    24     Gisele Andrade                   566657      6
# 3    29     Gisele Andrade                   566657      6
# 24  372            Heloísa                   567470      6
# 25  373            Heloísa                   567470      6
# 70  305         João Pedro                   568397      6
#
#     DEntrevistado_curso         Satisfação_curso  Idade     Gênero  \
# 2   Ciências Ambientais  Parcialmente satisfeito     25   Feminino
# 3   Ciências Ambientais         Muito satisfeito     22   Feminino
# 24  Ciências Ambientais         Muito satisfeito     20   Feminino
# 25  Ciências Ambientais  Parcialmente satisfeito     18  Masculino
# 70  Ciências Ambientais  Parcialmente satisfeito     24  Masculino
#
#                                    Moradia anterior  \
# 2                                         Fortaleza
# 3                                         Fortaleza
# ...

# %%
#outra condição
dados.loc[dados['Idade'] > 25]
# Out:
#      id Entrevistador_nome  Entrevistador_matrícula  grupo  \
# 7    57     Gisele Andrade                   566657      6
# 16  145            Heloísa                   567470      6
# 44  452            Heloísa                   567470      6
# 49  573              Orfeu                   567836      6
# 65  259         João Pedro                   568397      6
# 68  288         João Pedro                   568397      6
# 72  390         João Pedro                   568397      6
#
#             DEntrevistado_curso  Satisfação_curso  Idade     Gênero  \
# 7   Ciências Marinhas Tropicais  Muito satisfeito     33  Masculino
# 16                    Geografia  Muito satisfeito     35  Masculino
# 44                       Letras  Muito satisfeito     26  Masculino
# 49             Ciência de Dados  Muito satisfeito     28  Masculino
# 65                     Farmácia  Muito satisfeito     26  Masculino
# 68          Pós em Farmacologia  Muito satisfeito     32   Feminino
# ...

# %%
#atribuindo resultado a variável, criando outro df
idade2= dados.loc[dados['Idade'] > 25]
print(idade2)
# Out:
#      id Entrevistador_nome  Entrevistador_matrícula  grupo  \
# 7    57     Gisele Andrade                   566657      6
# 16  145            Heloísa                   567470      6
# 44  452            Heloísa                   567470      6
# 49  573              Orfeu                   567836      6
# 65  259         João Pedro                   568397      6
# 68  288         João Pedro                   568397      6
# 72  390         João Pedro                   568397      6
#
#             DEntrevistado_curso  Satisfação_curso  Idade     Gênero  \
# 7   Ciências Marinhas Tropicais  Muito satisfeito     33  Masculino
# 16                    Geografia  Muito satisfeito     35  Masculino
# 44                       Letras  Muito satisfeito     26  Masculino
# 49             Ciência de Dados  Muito satisfeito     28  Masculino
# 65                     Farmácia  Muito satisfeito     26  Masculino
# 68          Pós em Farmacologia  Muito satisfeito     32   Feminino
# ...

# %%
#definindo apenas algumas colunas
idade3 = dados[['DEntrevistado_curso','grupo','Idade']].loc[dados['Idade'] > 25]
print(idade3)
# Out:
#             DEntrevistado_curso  grupo  Idade
# 7   Ciências Marinhas Tropicais      6     33
# 16                    Geografia      6     35
# 44                       Letras      6     26
# 49             Ciência de Dados      6     28
# 65                     Farmácia      6     26
# 68          Pós em Farmacologia      6     32
# 72               Design de Moda      6     26

# %%
#séries, unica coluna
s1 = pd.Series([2,5,3,34,45,23,1,16])
print(s1)
# Out:
# 0     2
# 1     5
# 2     3
# 3    34
# 4    45
# 5    23
# 6     1
# 7    16
# dtype: int64

# %%
#series a partir de um dataframe
s3 = dados['Idade']
print(s3)
# Out:
# 0     20
# 1     21
# 2     25
# 3     22
# 4     19
#       ..
# 73    20
# 74    18
# 75    22
# 76    18
# 77    19
# Name: Idade, Length: 78, dtype: int64

# %%
d4 = dados[['Idade']]
type(d4)
# Out:
# pandas.core.frame.DataFrame

# %%
#renomear -> inplace = true serve para fazer persistir
dados.rename(columns={"Idade":"idade"})
# Out:
#      id Entrevistador_nome  Entrevistador_matrícula  grupo  \
# 0    19     Gisele Andrade                   566657      6
# 1    21     Gisele Andrade                   566657      6
# 2    24     Gisele Andrade                   566657      6
# 3    29     Gisele Andrade                   566657      6
# 4    36     Gisele Andrade                   566657      6
# ..  ...                ...                      ...    ...
# 73  210        Victor Hugo                   569696      6
# 74  214        Victor Hugo                   569696      6
# 75  241        Victor Hugo                   569696      6
# 76  634        Victor Hugo                   569696      6
# 77  638        Victor Hugo                   569696      6
#
#     DEntrevistado_curso           Satisfação_curso  idade     Gênero  \
# 0            Jornalismo           Muito satisfeito     20  Masculino
# 1       Educação Física    Parcialmente satisfeito     21   Feminino
# ...

# %%
dados.head(1)
# Out:
#    id Entrevistador_nome  Entrevistador_matrícula  grupo DEntrevistado_curso  \
# 0  19     Gisele Andrade                   566657      6          Jornalismo
#
#    Satisfação_curso  idade     Gênero Moradia anterior Encontro  \
# 0  Muito satisfeito     20  Masculino        Fortaleza      PET
#
#   A qualidade da sua vida   Interação social              Alimentação  \
# 0       Melhorou bastante  Aumentou bastante  nem melhorou nem piorou
#
#               Saude mental         Convívio família
# 0  nem melhorou nem piorou  nem melhorou nem piorou

# %%
#excluir coluna
dados.drop('Entrevistador_matrícula', axis=1, inplace=True)
print(dados)
# Out:
#    Entrevistador_nome  grupo  DEntrevistado_curso           Satisfação_curso  \
# 0      Gisele Andrade      6           Jornalismo           Muito satisfeito
# 1      Gisele Andrade      6      Educação Física    Parcialmente satisfeito
# 2      Gisele Andrade      6  Ciências Ambientais    Parcialmente satisfeito
# 3      Gisele Andrade      6  Ciências Ambientais           Muito satisfeito
# 4      Gisele Andrade      6  Ciências Biológicas    Parcialmente satisfeito
# ..                ...    ...                  ...                        ...
# 73        Victor Hugo      6  Engenharia Mecânica  Parcialmente insatisfeito
# 74        Victor Hugo      6           Psicologia    Parcialmente satisfeito
# 75        Victor Hugo      6            Filosofia           Muito satisfeito
# 76        Victor Hugo      6             Farmácia           Muito satisfeito
# 77        Victor Hugo      6             Economia  Parcialmente insatisfeito
#
# ...

# %%
dados.isnull().sum()
# Out:
# Entrevistador_nome         0
# grupo                      0
# DEntrevistado_curso        0
# Satisfação_curso           0
# idade                      0
# Gênero                     0
# Moradia anterior           0
# Encontro                   0
# A qualidade da sua vida    0
# Interação social           0
# Alimentação                0
# Saude mental               0
# Convívio família           0
# dtype: int64

# %%
dados.dropna()
# Out:
#    Entrevistador_nome  grupo  DEntrevistado_curso           Satisfação_curso  \
# 0      Gisele Andrade      6           Jornalismo           Muito satisfeito
# 1      Gisele Andrade      6      Educação Física    Parcialmente satisfeito
# 2      Gisele Andrade      6  Ciências Ambientais    Parcialmente satisfeito
# 3      Gisele Andrade      6  Ciências Ambientais           Muito satisfeito
# 4      Gisele Andrade      6  Ciências Biológicas    Parcialmente satisfeito
# ..                ...    ...                  ...                        ...
# 73        Victor Hugo      6  Engenharia Mecânica  Parcialmente insatisfeito
# 74        Victor Hugo      6           Psicologia    Parcialmente satisfeito
# 75        Victor Hugo      6            Filosofia           Muito satisfeito
# 76        Victor Hugo      6             Farmácia           Muito satisfeito
# 77        Victor Hugo      6             Economia  Parcialmente insatisfeito
#
# ...

# %%
#selecionar dados pelo id
dados.iloc[0:3,0:5]
# Out:
#   Entrevistador_nome  grupo  DEntrevistado_curso         Satisfação_curso  \
# 0     Gisele Andrade      6           Jornalismo         Muito satisfeito
# 1     Gisele Andrade      6      Educação Física  Parcialmente satisfeito
# 2     Gisele Andrade      6  Ciências Ambientais  Parcialmente satisfeito
#
#    idade
# 0     20
# 1     21
# 2     25

# %%
dados.iloc[[0,1,2,3,7],0:5]
# Out:
#   Entrevistador_nome  grupo          DEntrevistado_curso  \
# 0     Gisele Andrade      6                   Jornalismo
# 1     Gisele Andrade      6              Educação Física
# 2     Gisele Andrade      6          Ciências Ambientais
# 3     Gisele Andrade      6          Ciências Ambientais
# 7     Gisele Andrade      6  Ciências Marinhas Tropicais
#
#           Satisfação_curso  idade
# 0         Muito satisfeito     20
# 1  Parcialmente satisfeito     21
# 2  Parcialmente satisfeito     25
# 3         Muito satisfeito     22
# 7         Muito satisfeito     33
